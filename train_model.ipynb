# %%
#clone the yolov5 github repository
# !git clone https://github.com/ultralytics/yolov5
# !pip install -r ./yolov5/requirements.txt

# %%
import os
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
# Out:
# GPU Available: True

# %%
os.chdir('./yolov5')

# %%
# !pip install roboflow

# %%
#license plate detection dataset
#download dataset from robolow
from roboflow import Roboflow
rf = Roboflow(api_key="2uoaDwmGBqRPBC2SKpka")
project = rf.workspace("carplates2").project("licenseplate_v2")
dataset = project.version(2).download("yolov5")
#to add more images find them and use the labelImg package to label
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to LicensePlate_v2-2 in yolov5pytorch:: 100%|██████████| 1604/1604 [00:00<00:00, 3084.16it/s]

# %%
#ocr character recognition dataset
from roboflow import Roboflow
rf = Roboflow(api_key="2uoaDwmGBqRPBC2SKpka")
project = rf.workspace("w251ocr").project("ocr-oy9a7")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to OCR-1 in yolov5pytorch:: 100%|██████████| 12164/12164 [00:02<00:00, 4337.84it/s]

# %%
import shutil
shutil.copyfile('./requirements.txt', '../requirements.txt')
# Out:
# '../requirements.txt'

# %%
#download model size and weights for transfer learning before training 
#https://github.com/ultralytics/yolov5
# train model on 100 epochs
# !python train.py --img 640 --batch 16 \
    --epochs 100 --data LicensePlate_v2-2/data.yaml \
    --weights yolov5m.pt --project trained_models --name license_plate_5m --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=LicensePlate_v2-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=trained_models, name=license_plate_5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-147-gaa7c45c Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python train.py --img 640 --batch 16 \
    --epochs 100 --data OCR-1/data.yaml \
    --weights yolov5s.pt --project trained_models --name ocr_5s --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=OCR-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=trained_models, name=ocr_5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-150-gbe61a64 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
